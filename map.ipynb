# %%
import matplotlib.pyplot as plt

# %%
y=list(range(20,50,3))
y1=[2,5,1,10,2,7,4,8,3,7]
x=list(range(10))

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y label')
plt.show()

# %%
plt.scatter(x,y)
